# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
dataset_name = "ufop"

# %%
if dataset_name == "minds":
    df = pd.read_csv("../00_datasets/dataset_output/libras_minds/libras_minds_openpose.csv")
    if "person" not in df.columns:
        import re
        df["person"] = df["video_name"].apply(lambda i: int(re.findall(r".*Sinalizador(\d+)-.+.mp4", i)[0]))
    
    dataset_normalized_name = "MINDS-Libras"
    num_person = 12
    categories = ["To happen", "Student", "Yellow", "America", "To enjoy", "Candy", "Bank", "Bathroom", "Noise", "Five", "To know", "Mirror", "Corner", "Son", "Apple", "Fear", "Bad", "Frog", "Vaccine", "Will"]
    
    df_categories = list(df["category"].unique())
    df["category"] = df["category"].apply(lambda i: categories[df_categories.index(i)])
    
if dataset_name == "ufop":
    df = pd.read_csv("../00_datasets/dataset_output/libras_ufop/libras_ufop_openpose.csv")
    dataset_normalized_name = "LIBRAS-UFOP"
    num_person = 5
    categories = ["Year 1", "Year 2", "Year 3", "Day 1", "Day 2", "Day 3", "Week 1", "Week", "Yesterday", "Day before yesterday", "Safe", "Physiotherapy", "Idea", "Stamp", "Record", "Effort", "Defend", "Physical education", "Bodybuilding", "Battle", "Close", "Screw up", "Bicycle", "Slip", "Always", "Build", "Calumny", "Work", "Television", "Love", "Learn", "Analyze", "Talk", "Cock", "Hen", "Interact", "Exchange", "Strong wind", "Weak wind", "Strong rain", "Weak rain", "Run fast", "Run slow", "Takes great care", "Takes a little care", "Thin", "Fat", "Strong", "Weak", "Arrive", "Win", "Loss", "Open", "Nothing", "Nobody", "Not"]
    categories_1 = ["Year 1", "Year 2", "Year 3", "Day 1", "Day 2", "Day 3", "Week 1", "Week", "Yesterday", "Day before yesterday"]
    categories_2 = ["Safe", "Physiotherapy", "Idea", "Day 1", "Stamp", "Record", "Effort", "Defend", "Physical education", "Bodybuilding", "Battle", "Close", "Screw up", "Bicycle", "Slip", "Always", "Build", "Calumny", "Work", "Television"]
    categories_3 = ["Love", "Learn", "Analyze", "Talk", "Cock", "Hen", "Interact", "Exchange"]
    categories_4 = ["Strong wind", "Weak wind", "Strong rain", "Weak rain", "Run fast", "Run slow", "Takes great care", "Takes a little care", "Thin", "Fat", "Strong", "Weak", "Arrive", "Win", "Loss", "Open", "Close", "Nothing", "Nobody", "Not"]
    df_categories = list(df["category"].unique())
    df["category"] = df["category"].apply(lambda i: categories[df_categories.index(i)])

if dataset_name == "ksl":
    df = pd.read_csv("../00_datasets/dataset_output/KSL/ksl_openpose.csv")
    if "person" not in df.columns:
        df["person"] = df["video_name"].apply(lambda i: int(i.split("\\")[1].split("_")[0]))
    dataset_normalized_name = "KSL"
    num_person = 20
    original_categories = ["hi", "what", "meat", "bi bim rice", "glad", "hobby", "me", "movie", "face", "see", "name", "read", "thank", "equal", "sorry", "eat", "fine", "do effort", "next", "age", "again", "how many", "day", "good, nice", "when", "we", "subway", "be friendly", "bus", "ride", "cell phone", "where", "number", "location", "guide", "responsibility", "who", "arrive", "family", "time", "introduction", "recieve", "please?", "walk", "parents", "10 minutes", "sister", "study", "human", "now", "special", "yesterday", "education", "test", "end", "you", "worried_about", "marry", "effort", "no", "sweat", "yet", "finally", "born", "success", "favor", "Seoul", "dinner", "experience", "invite", "food", "want", "visit", "one hour", "far", "good", "care"]
    categories = [i.capitalize() for j, i in enumerate(original_categories) if (j + 1) not in (12, 19, 28, 33, 35, 45, 46, 53, 73, 75)]
    df_categories = list(df["category"].unique())
    df["category"] = df["category"].apply(lambda i: categories[df_categories.index(i)])
    
if dataset_name == "include50":
    df = pd.read_csv("../00_datasets/dataset_output/include50/include50_openpose.csv")
    categories = ['Loud', 'Mean', 'Rich', 'Poor', 'Thick', 'Thin', 'Expensive', 'Cheap', 'Flat', 'Curved', 'Male', 'Quiet', 'Female', 'Tight', 'Loose', 'High', 'Low', 'Soft', 'Hard', 'Deep', 'Shallow', 'Clean', 'Happy', 'Dirty', 'Strong', 'Weak', 'Dead', 'Alive', 'Heavy', 'Light', 'Famous', 'Sad', 'Beautiful', 'Ugly', 'Deaf', 'Long', 'Short', 'Blind', 'Tall', 'Wide', 'Narrow', 'Big large', 'Small little', 'Slow', 'Fast', 'Hot', 'Cold', 'Warm', 'Nice', 'Cool', 'New', 'Old', 'Young', 'Good', 'Bad', 'Wet', 'Dry', 'Sick', 'Healthy', 'Dog', 'Cat', 'Fish', 'Bird', 'Cow', 'Mouse', 'Horse', 'Animal', 'Hat', 'Dress', 'Suit', 'Skirt', 'Shirt', 'T-shirt', 'Pant', 'Shoes', 'Pocket', 'Clothing', 'Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Today', 'Tomorrow', 'Yesterday', 'Week', 'Month', 'Year', 'Hour', 'Minute', 'Second', 'Morning', 'Afternoon', 'Evening', 'Night', 'Time', 'Clock', 'Lamp', 'Fan', 'Cell phone', 'Computer', 'Laptop', 'Screen', 'Camera', 'Television', 'Radio', 'Hello', 'How are you', 'Alright', 'Good morning', 'Good afternoon', 'Good evening', 'Good night', 'Thank you', 'Pleased', 'Table', 'Chair', 'Bed', 'Dream', 'Window', 'Door', 'Bedroom', 'Kitchen', 'Bathroom', 'Pencil', 'Pen', 'Photograph', 'Soap', 'Book', 'Page', 'Key', 'Paint', 'Letter', 'Paper', 'Lock', 'Telephone', 'Bag', 'Box', 'Gift', 'Card', 'Ring', 'Tool', 'Teacher', 'Student', 'Lawyer', 'Doctor', 'Patient', 'Waiter', 'Secretary', 'Priest', 'Police', 'Soldier', 'Artist', 'Author', 'Manager', 'Reporter', 'Actor', 'Job', 'Plane', 'Car', 'Truck', 'Bicycle', 'Bus', 'Boat', 'Train ticket', 'Transportation', 'Train', 'Son', 'Daughter', 'Mother', 'Father', 'Parent', 'Baby', 'Man', 'Woman', 'Brother', 'Sister', 'Family', 'Grandfather', 'Grandmother', 'Husband', 'Wife', 'King', 'Queen', 'President', 'Neighbour', 'Boy', 'Girl', 'Child', 'Adult', 'Friend', 'Player', 'Crowd', 'City', 'House', 'Street or road', 'Train station', 'Restaurant', 'Court', 'School', 'Office', 'University', 'Park', 'Store or shop', 'Library', 'Hospital', 'Temple', 'Market', 'India', 'Ground', 'Bank', 'Location', 'I', 'You', 'He', 'She', 'It', 'We', 'You (plural)', 'They', 'Summer', 'Spring', 'Winter', 'Fall', 'Season', 'Monsoon', 'Religion', 'Energy', 'War', 'Peace', 'Attack', 'Election', 'Newspaper', 'Gun', 'Sport', 'Exercise', 'Ball', 'Death', 'Price', 'Sign', 'Science', 'God', 'Medicine', 'Money', 'Bill', 'Marriage', 'Team', 'Race (ethnicity)', 'Technology']
    num_person = 0

# %%
if dataset_name == "include50":
    base_path = "../00_datasets/dataset_output/include50/"
    train_file = "include50_train.txt"
    validate_file = "include50_val.txt"
    test_file = "include50_test.txt"

    def read_file(filename):
        with open(filename) as file:
            lines = [line.rstrip() for line in file]
        return lines

    with open(base_path + train_file) as file:
        train_videos = [line.rstrip().lower().replace(".mov", "").replace(".mp4", "") for line in file]

    with open(base_path + test_file) as file:
        test_videos = [line.rstrip().lower().replace(".mov", "").replace(".mp4", "") for line in file]

    with open(base_path + validate_file) as file:
        validate_videos = [line.rstrip().lower().replace(".mov", "").replace(".mp4", "") for line in file]
        
    df["video_path"] = df.apply(lambda i: (i["video_name"].replace("\\", "/")).lower().replace(".mov", "").replace(".mp4", ""), axis=1)
    df["person"] = -1
    df.loc[df["video_path"].isin(train_videos), "person"] = 0
    df.loc[df["video_path"].isin(validate_videos), "person"] = 1
    df.loc[df["video_path"].isin(test_videos), "person"] = 2

    df = df[df["person"] != -1]

# %%
df
# Out:
#        category   video_name  frame  hand_0_0_x  hand_0_0_y  hand_0_0_z  \
# 0        Year 1   p1_c1_s1_0      0    0.555807    0.567531    0.394245
# 1        Year 1   p1_c1_s1_0      1    0.555086    0.561309    0.396433
# 2        Year 1   p1_c1_s1_0      2    0.552441    0.554763    0.376937
# 3        Year 1   p1_c1_s1_0      3    0.540484    0.558278    0.014662
# 4        Year 1   p1_c1_s1_0      4    0.539812    0.537244    0.100900
# ...         ...          ...    ...         ...         ...         ...
# 202484      Not  p5_c4_s9_10     36    0.511064    0.446786    0.026157
# 202485      Not  p5_c4_s9_10     37    0.539804    0.431748    0.028773
# 202486      Not  p5_c4_s9_10     38    0.542277    0.441707    0.030453
# 202487      Not  p5_c4_s9_10     39    0.540754    0.450658    0.036463
# 202488      Not  p5_c4_s9_10     40    0.522440    0.436927    0.275950
#
#         hand_0_1_x  hand_0_1_y  hand_0_1_z  hand_0_2_x  ...  pose_22_z  \
# 0         0.549136    0.575092    0.414851    0.543798  ...   0.753184
# 1         0.547985    0.570326    0.402954    0.542236  ...   0.751818
# 2         0.544950    0.563844    0.328017    0.539501  ...   0.721404
# 3         0.539830    0.565252    0.043459    0.532311  ...   0.745815
# 4         0.534094    0.548904    0.083215    0.531067  ...   0.697552
# ...            ...         ...         ...         ...  ...        ...
# 202484    0.538449    0.420391    0.030119    0.526901  ...   0.752672
# 202485    0.541779    0.429114    0.030089    0.534208  ...   0.725757
# 202486    0.542592    0.434997    0.080483    0.521517  ...   0.722870
# 202487    0.534091    0.436443    0.065288    0.541753  ...   0.716687
# 202488    0.533989    0.446403    0.045277    0.532805  ...   0.705954
#
#         pose_23_x  pose_23_y  pose_23_z  pose_24_x  pose_24_y  pose_24_z  \
# 0        0.433065   0.966341   0.781661   0.449489   0.928342   0.651774
# 1        0.433051   0.966384   0.792620   0.449503   0.930953   0.673173
# 2        0.431155   0.966412   0.771990   0.449501   0.928337   0.667928
# 3        0.433046   0.966367   0.777363   0.449523   0.928312   0.661847
# 4        0.433064   0.966390   0.749232   0.449475   0.930948   0.649300
# ...           ...        ...        ...        ...        ...        ...
# 202484   0.424943   0.955436   0.677236   0.439216   0.898344   0.543393
# 202485   0.424950   0.950097   0.681652   0.437225   0.901135   0.545763
# 202486   0.426986   0.952731   0.657443   0.435220   0.898388   0.555769
# 202487   0.424990   0.952775   0.658890   0.437217   0.901061   0.537380
# 202488   0.426990   0.950059   0.665721   0.437205   0.898362   0.538676
#
#         missing_hand  missing_face  person
# 0              False         False     1.0
# 1              False         False     1.0
# 2              False         False     1.0
# 3              False         False     1.0
# 4              False         False     1.0
# ...              ...           ...     ...
# 202484         False         False     5.0
# 202485         False         False     5.0
# 202486         False         False     5.0
# 202487         False         False     5.0
# 202488         False         False     5.0
#
# [202489 rows x 417 columns]

# %%
len(df["video_name"].unique())
# Out:
# 3040

# %%
df_videos = df[df["frame"] == 0]

# %%
df_videos.count()
# Out:
# Unnamed: 0      956
# category        956
# video_name      956
# frame           956
# hand_0_0_x      956
#                ...
# pose_24_z       956
# missing_hand    956
# missing_face    956
# person          956
# video_path      956
# Length: 419, dtype: int64

# %%
len(df_videos)
# Out:
# 956

# %%
len(df_videos[df_videos["person"] == 0])
# Out:
# 687

# %%
len(df_videos[df_videos["person"] == 1])
# Out:
# 77

# %%
len(df_videos[df_videos["person"] == 2])
# Out:
# 192

# %%
len(df_videos["category"].unique())
# Out:
# 50

# %%
len(df_videos["person"].unique())
# Out:
# 3

# %%
# (10, 6)

# %%
counts = df_videos.groupby("category").count()[["frame"]]
ax = counts.plot(kind="bar", figsize=(18, 4), width=0.6)

ax.set(ylim=[counts.min()[0] - 2, counts.max()[0] + 2])

mean = counts.mean()["frame"]
plt.axhline(y=mean, color="red", zorder=0, linestyle='--')

font_size= 14
# plt.axhline(y=mean, color="red")

print(f"Mean: {mean}")

plt.xlabel("Category", fontsize=font_size)
plt.ylabel("Video count", fontsize=font_size)
plt.legend([]).remove()
plt.xticks(rotation=90, ha="center", fontsize=font_size)
plt.yticks(fontsize=font_size)

for container in ax.containers:
    ax.bar_label(container, fmt='%.0f', label_type='edge', padding=3, fontsize=font_size)
# Out:
# Mean: 19.12

# %%
counts
# Out:
#            frame
# category
# America       55
# Apple         60
# Bad           60
# Bank          60
# Bathroom      55
# Candy         60
# Corner        55
# Fear          55
# Five          55
# Frog          60
# Mirror        60
# Noise         62
# Son           56
# Student       55
# To enjoy      60
# To happen     60
# To know       55
# Vaccine       60
# Will          60
# Yellow        55

# %%
counts.value_counts()
# Out:
# frame
# 60       10
# 55        8
# 56        1
# 62        1
# Name: count, dtype: int64

# %%
counts, edges, bars = plt.hist(counts)
plt.title("")
plt.xlabel("Number of videos", fontsize=font_size)
plt.ylabel("Number of signs", fontsize=font_size)

plt.bar_label(bars, fontsize=font_size)

plt.xticks(fontsize=font_size)
plt.yticks(fontsize=font_size)
# Out:
# (array([0., 1., 2., 3., 4., 5., 6., 7.]),
#  [Text(0, 0.0, '0'),
#   Text(0, 1.0, '1'),
#   Text(0, 2.0, '2'),
#   Text(0, 3.0, '3'),
#   Text(0, 4.0, '4'),
#   Text(0, 5.0, '5'),
#   Text(0, 6.0, '6'),
#   Text(0, 7.0, '7')])

# %%
counts.boxplot()
plt.xticks([1], [''])
# Out:
# ([<matplotlib.axis.XTick at 0x7f031bc40760>], [Text(1, 0, '')])

# %%
counts.mean()
# Out:
# frame    54.285714
# dtype: float64

# %%
counts.mean()["frame"]
# Out:
# 54.285714285714285

# %%
counts.std()
# Out:
# frame    3.581337
# dtype: float64

# %%
counts = df_videos.groupby("person").count()[["category"]]
ax = counts.plot(kind="bar", figsize=(10, 4))
ax.set(ylim=[counts.min()[0] - 5, counts.max()[0] + 4])

mean = counts.mean()["category"]
plt.axhline(y=mean, color="red", zorder=0, linestyle='--')

plt.xlabel("Signaler", fontsize=font_size)
plt.ylabel("Video count", fontsize=font_size)
plt.legend([]).remove()

for container in ax.containers:
    ax.bar_label(container, fmt='%.0f', label_type='edge', padding=3, fontsize=font_size)
    
plt.xticks(rotation=0, ha="center", fontsize=font_size)
plt.yticks(fontsize=font_size)
# Out:
# (array([30., 35., 40., 45., 50., 55., 60., 65., 70., 75.]),
#  [Text(0, 30.0, '30'),
#   Text(0, 35.0, '35'),
#   Text(0, 40.0, '40'),
#   Text(0, 45.0, '45'),
#   Text(0, 50.0, '50'),
#   Text(0, 55.0, '55'),
#   Text(0, 60.0, '60'),
#   Text(0, 65.0, '65'),
#   Text(0, 70.0, '70'),
#   Text(0, 75.0, '75')])

# %%
counts = df_videos[df_videos["category"].isin(categories_4)]
counts = counts.groupby("category").count()[["person"]]

mean = counts.mean()["person"]
print(f"Mean: {mean}")
std = counts.std()["person"]
print(f"Std: {std}")
ax = counts.plot(kind="bar", figsize=(14, 4), fontsize=font_size)
ax.set(ylim=[counts.min()[0] - 5, counts.max()[0] + 2])
plt.axhline(y=mean, color="red", zorder=0, linestyle='--')

plt.xlabel("Category", fontsize=font_size)
plt.ylabel("Video count", fontsize=font_size)
plt.legend([]).remove()

for container in ax.containers:
    ax.bar_label(container, fmt='%.0f', label_type='edge', padding=3, fontsize=font_size)
    

plt.xticks(rotation=45, ha="right", fontsize=font_size)
plt.yticks(fontsize=font_size)
# Out:
# Mean: 53.0
# Std: 3.0607876523260447
# (array([44., 46., 48., 50., 52., 54., 56., 58., 60., 62., 64.]),
#  [Text(0, 44.0, '44'),
#   Text(0, 46.0, '46'),
#   Text(0, 48.0, '48'),
#   Text(0, 50.0, '50'),
#   Text(0, 52.0, '52'),
#   Text(0, 54.0, '54'),
#   Text(0, 56.0, '56'),
#   Text(0, 58.0, '58'),
#   Text(0, 60.0, '60'),
#   Text(0, 62.0, '62'),
#   Text(0, 64.0, '64')])
